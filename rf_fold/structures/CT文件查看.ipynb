# %%
import numpy as np

# %%
strc_ric = np.loadtxt('JX188454.1.ct', usecols=[0,1,2,3,4,5], dtype=[('1','<i4'),('2','<S2'),('3','<i4'),('4','<i4'),('5','<i4'), ('6','<i4')], skiprows=1)

# %%
def select_strc(ct_f, s, e, types = 'rna_strc'):
    strc_selet = ct_f[s-1:e].copy()
    mask = (strc_selet['5'] < s) | (strc_selet['5'] >= e)
    strc_selet['5'][mask] = 0
    if types == 'rna_strc':
        strc_selet['1'] = strc_selet['1'] - s +1
        strc_selet['3'] = strc_selet['3'] - s +1
        strc_selet['4'] = strc_selet['4'] - s +1
        strc_selet['5'][strc_selet['5']>0] = strc_selet['5'][strc_selet['5']>0] - s +1
        strc_selet['6'] = strc_selet['6'] - s +1
    return strc_selet

# %%
s = 0 #1750:2050; 2100:2380;
e = 600

# %%
ric_1 = select_strc(strc_ric, s, e)
np.savetxt('PEDV_0-2810'+str(s)+'-'+str(e)+'.ct', ric_1, fmt = '%s')

# %%
with open('C:/Users/aaa/Desktop/draw2/SARS-CoV-2-ric-seq'+str(s)+'-'+str(e)+'.ct', 'w') as f:
    with open('C:/Users/aaa/Desktop/draw2/SARS-CoV-2-ric-seq.ct'+str(s)+'-'+str(e)+'.ct','r')as F:
        for l in F:
            a=l.split(' ')[1];b=list(a);c=b[2]
            if a.startswith('b'):
                d=l.replace(a,c)
                f.write(d)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 with open('C:/Users/aaa/Desktop/draw2/SARS-CoV-2-ric-seq'+str(s)+'-'+str(e)+'.ct', 'w') as f:
#       2     with open('C:/Users/aaa/Desktop/draw2/SARS-CoV-2-ric-seq.ct'+str(s)+'-'+str(e)+'.ct','r')as F:
#       3         for l in F:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/aaa/Desktop/draw2/SARS-CoV-2-ric-seq0-600.ct'

# %%
ric_1 = select_strc(strc_ric, s, e)
np.savetxt('JX188454.1.ct'+str(s)+'-'+str(e)+'.ct', ric_1, fmt = '%s')
with open('PEDV_0-2810'+str(s)+'-'+str(e)+'.ct', 'w') as f:
    with open(''+str(s)+'-'+str(e)+'.ct','r')as F:
        for l in F:
            a=l.split(' ')[1];b=list(a);c=b[2]
            if a.startswith('b'):
                d=l.replace(a,c)
                f.write(d)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [7], in <cell line: 3>()
#       2 np.savetxt('JX188454.1.ct'+str(s)+'-'+str(e)+'.ct', ric_1, fmt = '%s')
#       3 with open('PEDV_0-2810'+str(s)+'-'+str(e)+'.ct', 'w') as f:
# ----> 4     with open(''+str(s)+'-'+str(e)+'.ct','r')as F:
#       5         for l in F:
#       6             a=l.split(' ')[1];b=list(a);c=b[2]
#
# FileNotFoundError: [Errno 2] No such file or directory: '0-2810.ct'

# %%
import numpy as np
strc_ric = np.loadtxt('JX188454.1.ct', usecols=[0,1,2,3,4,5], dtype=[('1','<i4'),('2','<S2'),('3','<i4'),('4','<i4'),('5','<i4'), ('6','<i4')], skiprows=1)

def select_strc(ct_f, s, e, types = 'rna_strc'):
    strc_selet = ct_f[s-1:e].copy()
    mask = (strc_selet['5'] < s) | (strc_selet['5'] >= e)
    strc_selet['5'][mask] = 0
    if types == 'rna_strc':
        strc_selet['1'] = strc_selet['1'] - s +1
        strc_selet['3'] = strc_selet['3'] - s +1
        strc_selet['4'] = strc_selet['4'] - s +1
        strc_selet['5'][strc_selet['5']>0] = strc_selet['5'][strc_selet['5']>0] - s +1
        strc_selet['6'] = strc_selet['6'] - s +1
    return strc_selet

s = 1 #1750:2050; 2100:2380;
e = 2810
ric_1 = select_strc(strc_ric, s, e)
np.savetxt('JX188454.1.ct'+str(s)+'-'+str(e)+'.ct', ric_1, fmt = '%s')
with open('JX188454.1.ct'+str(s)+'-'+str(e)+'.ct', 'w') as f:
    with open(''+str(s)+'-'+str(e)+'.ct','r')as F:
        for l in F:
            a=l.split(' ')[1];b=list(a);c=b[2]
            if a.startswith('b'):
                d=l.replace(a,c)
                f.write(d)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [12], in <cell line: 20>()
#      19 np.savetxt('JX188454.1.ct'+str(s)+'-'+str(e)+'.ct', ric_1, fmt = '%s')
#      20 with open('JX188454.1.ct'+str(s)+'-'+str(e)+'.ct', 'w') as f:
# ---> 21     with open(''+str(s)+'-'+str(e)+'.ct','r')as F:
#      22         for l in F:
#      23             a=l.split(' ')[1];b=list(a);c=b[2]
#
# FileNotFoundError: [Errno 2] No such file or directory: '1-2810.ct'

# %%
strc_ric = np.loadtxt('JX188454.1.ct', usecols=[0,1,2,3,4,5], dtype=[('1','<i4'),('2','<S2'),('3','<i4'),('4','<i4'),('5','<i4'), ('6','<i4')], skiprows=1)

# %%
strc_ric.size
# Out:
# 28044

# %%
strc_ric.shape
# Out:
# (28044,)

# %%
strc_ric
# Out:
# array([(    1, b'A',     0,     2, 145,     1),
#        (    2, b'C',     1,     3, 144,     2),
#        (    3, b'U',     2,     4, 143,     3), ...,
#        (28042, b'A', 28041, 28043,   0, 28042),
#        (28043, b'A', 28042, 28044,   0, 28043),
#        (28044, b'A', 28043, 28045,   0, 28044)],
#       dtype=[('1', '<i4'), ('2', 'S2'), ('3', '<i4'), ('4', '<i4'), ('5', '<i4'), ('6', '<i4')])

# %%
def select_strc(ct_f, s, e, types = 'rna_strc'):
    strc_selet = ct_f[s-1:e].copy()
    mask = (strc_selet['5'] < s) | (strc_selet['5'] >= e)
    strc_selet['5'][mask] = 0
    if types == 'rna_strc':
        strc_selet['1'] = strc_selet['1'] - s +1
        strc_selet['3'] = strc_selet['3'] - s +1
        strc_selet['4'] = strc_selet['4'] - s +1
        strc_selet['5'][strc_selet['5']>0] = strc_selet['5'][strc_selet['5']>0] - s +1
        strc_selet['6'] = strc_selet['6'] - s +1
    return strc_selet

# %%
s = 1 #1750:2050; 2100:2380;
e = 600
ric_1 = select_strc(strc_ric, s, e)

# %%
ric_1
# Out:
# array([(  1, b'A',   0,   2, 145,   1), (  2, b'C',   1,   3, 144,   2),
#        (  3, b'U',   2,   4, 143,   3), (  4, b'U',   3,   5, 142,   4),
#        (  5, b'A',   4,   6, 141,   5), (  6, b'A',   5,   7, 140,   6),
#        (  7, b'A',   6,   8,  39,   7), (  8, b'A',   7,   9,  38,   8),
#        (  9, b'A',   8,  10,  37,   9), ( 10, b'G',   9,  11,  36,  10),
#        ( 11, b'A',  10,  12,  35,  11), ( 12, b'U',  11,  13,  33,  12),
#        ( 13, b'U',  12,  14,  32,  13), ( 14, b'U',  13,  15,   0,  14),
#        ( 15, b'U',  14,  16,   0,  15), ( 16, b'C',  15,  17,  29,  16),
#        ( 17, b'U',  16,  18,  28,  17), ( 18, b'A',  17,  19,  27,  18),
#        ( 19, b'U',  18,  20,  26,  19), ( 20, b'C',  19,  21,  25,  20),
#        ( 21, b'U',  20,  22,   0,  21), ( 22, b'A',  21,  23,   0,  22),
#        ( 23, b'C',  22,  24,   0,  23), ( 24, b'G',  23,  25,   0,  24),
#        ( 25, b'G',  24,  26,  20,  25), ( 26, b'A',  25,  27,  19,  26),
# ...

# %%
np.savetxt(''+str(s)+'-'+str(e)+'.ct', ric_1, fmt = '%s')
with open('JX188454.1.ct'+str(s)+'-'+str(e)+'.ct', 'w') as f:
    with open('JX188454.1.ct'+str(s)+'-'+str(e)+'.ct','r')as F:
        for l in F:
            a=l.split(' ')[1];b=list(a);c=b[2]
            if a.startswith('b'):
                d=l.replace(a,c)
                f.write(d)

# %%
# %pwd
# Out:
# '/Users/wang/Downloads/rf_fold/structures'

# %%
ric_1
# Out:
# array([(  1, b'A',   0,   2, 145,   1), (  2, b'C',   1,   3, 144,   2),
#        (  3, b'U',   2,   4, 143,   3), (  4, b'U',   3,   5, 142,   4),
#        (  5, b'A',   4,   6, 141,   5), (  6, b'A',   5,   7, 140,   6),
#        (  7, b'A',   6,   8,  39,   7), (  8, b'A',   7,   9,  38,   8),
#        (  9, b'A',   8,  10,  37,   9), ( 10, b'G',   9,  11,  36,  10),
#        ( 11, b'A',  10,  12,  35,  11), ( 12, b'U',  11,  13,  33,  12),
#        ( 13, b'U',  12,  14,  32,  13), ( 14, b'U',  13,  15,   0,  14),
#        ( 15, b'U',  14,  16,   0,  15), ( 16, b'C',  15,  17,  29,  16),
#        ( 17, b'U',  16,  18,  28,  17), ( 18, b'A',  17,  19,  27,  18),
#        ( 19, b'U',  18,  20,  26,  19), ( 20, b'C',  19,  21,  25,  20),
#        ( 21, b'U',  20,  22,   0,  21), ( 22, b'A',  21,  23,   0,  22),
#        ( 23, b'C',  22,  24,   0,  23), ( 24, b'G',  23,  25,   0,  24),
#        ( 25, b'G',  24,  26,  20,  25), ( 26, b'A',  25,  27,  19,  26),
# ...
